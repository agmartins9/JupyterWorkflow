# %%
from pyspark import SparkContext
from pyspark.sql import SQLContext


sc = SparkContext('local', 'Spark SQL') 
spark = SQLContext(sc)
from pyspark.sql.functions import explode, col

# %%
source_df = spark.read.option("multiline", "true").json("prize.json")
source_df.printSchema()
source_df.show(5, False)
# Out:
# root
#  |-- prizes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- category: string (nullable = true)
#  |    |    |-- laureates: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- firstname: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- motivation: string (nullable = true)
#  |    |    |    |    |-- share: string (nullable = true)
#  |    |    |    |    |-- surname: string (nullable = true)
#  |    |    |-- overallMotivation: string (nullable = true)
#  |    |    |-- year: string (nullable = true)
#
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |prizes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[[chemistry, [[John, 976, "for the development of lithium-ion batteries", 3, Goodenough], [M. Stanley, 977, "for the development of lithium-ion batteries", 3, Whittingham], [Akira, 978, "for the development of lithium-ion batteries", 3, Yoshino]],, 2019], [economics, [[Abhijit, 982, "for their experimental approach to alleviating global poverty", 3, Banerjee], [Esther, 983, "for their experimental approach to alleviating global poverty", 3, Duflo], [Michael, 984, "for their experimental approach to alleviating global poverty", 3, Kremer]],, 2019], [literature, [[Peter, 980, "for an influential work that with linguistic ingenuity has explored the periphery and the specificity of human experience", 1, Handke]],, 2019], [peace, [[Abiy, 981, "for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea", 1, Ahmed Ali]],, 2019], [physics, [[James, 973, "for theoretical discoveries in physical cosmology", 2, Peebles], [Michel, 974, "for the discovery of an exoplanet orbiting a solar-type star", 4, Mayor], [Didier, 975, "for the discovery of an exoplanet orbiting a solar-type star", 4, Queloz]], "for contributions to our understanding of the evolution of the universe and Earth’s place in the cosmos", 2019], [medicine, [[William, 970, "for their discoveries of how cells sense and adapt to oxygen availability", 3, Kaelin], [Peter, 971, "for their discoveries of how cells sense and adapt to oxygen availability", 3, Ratcliffe], [Gregg, 972, "for their discoveries of how cells sense and adapt to oxygen availability", 3, Semenza]],, 2019], [chemistry, [[Frances H., 963, "for the directed evolution of enzymes", 2, Arnold], [George P., 964, "for the phage display of peptides and antibodies", 4, Smith], [Sir Gregory P., 965, "for the phage display of peptides and antibodies", 4, Winter]],, 2018], [economics, [[William D., 968, "for integrating climate change into long-run macroeconomic analysis", 2, Nordhaus], [Paul M., 969, "for integrating technological innovations into long-run macroeconomic analysis", 2, Romer]],, 2018], [literature, [[Olga, 979, "for a narrative imagination that with encyclopedic passion represents the crossing of boundaries as a form of life", 1, Tokarczuk]],, 2018], [peace, [[Denis, 966, "for their efforts to end the use of sexual violence as a weapon of war and armed conflict", 2, Mukwege], [Nadia, 967, "for their efforts to end the use of sexual violence as a weapon of war and armed conflict", 2, Murad]],, 2018], [physics, [[Arthur, 960, "for the optical tweezers and their application to biological systems", 2, Ashkin], [Gérard, 961, "for their method of generating high-intensity, ultra-short optical pulses", 4, Mourou], [Donna, 962, "for their method of generating high-intensity, ultra-short optical pulses", 4, Strickland]], "for groundbreaking inventions in the field of laser physics", 2018], [medicine, [[James P., 958, "for their discovery of cancer therapy by inhibition of negative immune regulation", 2, Allison], [Tasuku, 959, "for their discovery of cancer therapy by inhibition of negative immune regulation", 2, Honjo]],, 2018], [chemistry, [[Jacques, 944, "for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution", 3, Dubochet], [Joachim, 945, "for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution", 3, Frank], [Richard, 946, "for developing cryo-electron microscopy for the high-resolution structure determination of biomolecules in solution", 3, Henderson]],, 2017], [economics, [[Richard H., 949, "for his contributions to behavioural economics", 1, Thaler]],, 2017], [literature, [[Kazuo, 947, "who, in novels of great emotional force, has uncovered the abyss beneath our illusory sense of connection with the world", 1, Ishiguro]],, 2017], [peace, [[International Campaign to Abolish Nuclear  ...
# uncovered the life-world of the occupation", 1, Modiano]],, 2014], [peace, [[Kailash, 913, "for their struggle against the suppression of children and young people and for the right of all children to education", 2, Satyarthi], [Malala, 914, "for their struggle against the suppression of children and young people and for the right of all children to education", 2, Yousafzai]],, 2014], [physics, [[Isamu, 906, "for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources", 3, Akasaki], [Hiroshi, 907, "for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources", 3, Amano], [Shuji, 908, "for the invention of efficient blue light-emitting diodes which has enabled bright and energy-saving white light sources", 3, Nakamura]],, 2014], [medicine, [[John, 903, "for their discoveries of cells that constitute a positioning system in the brain", 2, O'Keefe], [May-Britt, 904, "for their discoveries of cells that constitute a positioning system in the brain", 4, Moser], [Edvard I., 905, "for their discoveries of cells that constitute a positioning system in the brain", 4, Moser]],, 2014], [chemistry, [[Martin, 889, "for the development of multiscale models for complex chemical systems", 3, Karplus], [Michael, 890, "for the development of multiscale models for complex chemical systems", 3, Levitt], [Arieh, 891, "for the development of multiscale models for complex chemical systems", 3, Warshel]],, 2013], [economics, [[Eugene F., 894, "for their empirical analysis of asset prices", 3, Fama], [Lars Peter, 895, "for their empirical analysis of asset prices", 3, Hansen], [Robert J., 896, "for their empirical analysis of asset prices", 3, Shiller]],, 2013], [literature, [[Alice, 892, "master of the contemporary short story", 1, Munro]],, 2013], [peace, [[Organisation for the Prohibition of Chemical Weapons, 893, "for its extensive efforts to eliminate chemical weapons", 1,]],, 2013], [physics, [[François, 887, "for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider", 2, Englert], [Peter, 888, "for the theoretical discovery of a mechanism that contributes to our understanding of the origin of mass of subatomic particles, and which recently was confirmed through the discovery of the predicted fundamental particle, by the ATLAS and CMS experiments at CERN's Large Hadron Collider", 2, Higgs]],, 2013], [medicine, [[James E., 884, "for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells", 3, Rothman], [Randy W., 885, "for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells", 3, Schekman], [Thomas C., 886, "for their discoveries of machinery regulating vesicle traffic, a major transport system in our cells", 3, Südhof]],, 2013], [chemistry, [[Robert J., 878, "for studies of G-protein-coupled receptors", 2, Lefkowitz], [Brian, 879, "for studies of G-protein-coupled receptors", 2, Kobilka]],, 2012], [economics, [[Alvin E., 882, "for the theory of stable allocations and the practice of market design", 2, Roth], [Lloyd S., 883, "for the theory of stable allocations and the practice of market design", 2, Shapley]],, 2012], [literature, [[Mo, 880, "who with hallucinatory realism merges folk tales, history and the contemporary", 1, Yan]],, 2012], [peace, [[European Union (EU), 881, "for over six decades contributed to the advancement of peace and reconciliation, democracy and human rights in Europe", 1,]],, 2012], [physics, [[Serge, 876, "for ground-breaking experimental methods that enable measuring and manipulation of individual quantum systems", 2, Haroche], [David J., 877, "for ground-breaking experimental methods that e ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
prizes = source_df.select(explode("prizes").alias("prizes"))
display(prizes)
prizes.printSchema()
prizes.show(5, False)
# Out:
# DataFrame[prizes: struct<category:string,laureates:array<struct<firstname:string,id:string,motivation:string,share:string,surname:string>>,overallMotivation:string,year:string>]
# root
#  |-- prizes: struct (nullable = true)
#  |    |-- category: string (nullable = true)
#  |    |-- laureates: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- firstname: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- motivation: string (nullable = true)
#  |    |    |    |-- share: string (nullable = true)
#  |    |    |    |-- surname: string (nullable = true)
#  |    |-- overallMotivation: string (nullable = true)
#  |    |-- year: string (nullable = true)
#
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |prizes                                                                                                                                                                                                                                                                                                                                                                                        |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[chemistry, [[John, 976, "for the development of lithium-ion batteries", 3, Goodenough], [M. Stanley, 977, "for the development of lithium-ion batteries", 3, Whittingham], [Akira, 978, "for the development of lithium-ion batteries", 3, Yoshino]],, 2019]                                                                                                                                 |
# |[economics, [[Abhijit, 982, "for their experimental approach to alleviating global poverty", 3, Banerjee], [Esther, 983, "for their experimental approach to alleviating global poverty", 3, Duflo], [Michael, 984, "for their experimental approach to alleviating global poverty", 3, Kremer]],, 2019]                                                                                      |
# |[literature, [[Peter, 980, "for an influential work that with linguistic ingenuity has explored the periphery and the specificity of human experience", 1, Handke]],, 2019]                                                                                                                                                                                                                   |
# |[peace, [[Abiy, 981, "for his efforts to achieve peace and international cooperation, and in particular for his decisive initiative to resolve the border conflict with neighbouring Eritrea", 1, Ahmed Ali]],, 2019]                                                                                                                                                                         |
# |[physics, [[James, 973, "for theoretical discoveries in physical cosmology", 2, Peebles], [Michel, 974, "for the discovery of an exoplanet orbiting a solar-type star", 4, Mayor], [Didier, 975, "for the discovery of an exoplanet orbiting a solar-type star", 4, Queloz]], "for contributions to our understanding of the evolution of the universe and Earth’s place in the cosmos", 2019]|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
prizes_laureates = prizes.select(
col("prizes.category").alias("prizes_category"),
explode("prizes.laureates").alias("prizes_laureates"),
col("prizes.overallMotivation").alias("prizes_overallMotivation"),
col("prizes.year").alias("prizes_year")
)
display(prizes_laureates)
prizes_laureates.printSchema()
prizes_laureates.show(5, False)
# Out:
# DataFrame[prizes_category: string, prizes_laureates: struct<firstname:string,id:string,motivation:string,share:string,surname:string>, prizes_overallMotivation: string, prizes_year: string]
# root
#  |-- prizes_category: string (nullable = true)
#  |-- prizes_laureates: struct (nullable = true)
#  |    |-- firstname: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- motivation: string (nullable = true)
#  |    |-- share: string (nullable = true)
#  |    |-- surname: string (nullable = true)
#  |-- prizes_overallMotivation: string (nullable = true)
#  |-- prizes_year: string (nullable = true)
#
# +---------------+--------------------------------------------------------------------------------------------+------------------------+-----------+
# |prizes_category|prizes_laureates                                                                            |prizes_overallMotivation|prizes_year|
# +---------------+--------------------------------------------------------------------------------------------+------------------------+-----------+
# |chemistry      |[John, 976, "for the development of lithium-ion batteries", 3, Goodenough]                  |null                    |2019       |
# |chemistry      |[M. Stanley, 977, "for the development of lithium-ion batteries", 3, Whittingham]           |null                    |2019       |
# |chemistry      |[Akira, 978, "for the development of lithium-ion batteries", 3, Yoshino]                    |null                    |2019       |
# |economics      |[Abhijit, 982, "for their experimental approach to alleviating global poverty", 3, Banerjee]|null                    |2019       |
# |economics      |[Esther, 983, "for their experimental approach to alleviating global poverty", 3, Duflo]    |null                    |2019       |
# +---------------+--------------------------------------------------------------------------------------------+------------------------+-----------+
# only showing top 5 rows

# %%
prizes_laureates_df = prizes_laureates.select(
col("prizes_category"),
col("prizes_overallMotivation"),
col("prizes_year"),
col("prizes_laureates.firstname").alias("prizes_laureates_firstname"),
col("prizes_laureates.id").alias("prizes_laureates_id"),
col("prizes_laureates.motivation").alias("prizes_laureates_motivation"),
col("prizes_laureates.share").alias("prizes_laureates_share"),
col("prizes_laureates.surname").alias("prizes_laureates_surname")    
)
display(prizes_laureates_df)
prizes_laureates_df.printSchema()
# Out:
# DataFrame[prizes_category: string, prizes_overallMotivation: string, prizes_year: string, prizes_laureates_firstname: string, prizes_laureates_id: string, prizes_laureates_motivation: string, prizes_laureates_share: string, prizes_laureates_surname: string]
# root
#  |-- prizes_category: string (nullable = true)
#  |-- prizes_overallMotivation: string (nullable = true)
#  |-- prizes_year: string (nullable = true)
#  |-- prizes_laureates_firstname: string (nullable = true)
#  |-- prizes_laureates_id: string (nullable = true)
#  |-- prizes_laureates_motivation: string (nullable = true)
#  |-- prizes_laureates_share: string (nullable = true)
#  |-- prizes_laureates_surname: string (nullable = true)

# %%
prizes_laureates_df.show(5, False)
# Out:
# +---------------+------------------------+-----------+--------------------------+-------------------+---------------------------------------------------------------+----------------------+------------------------+
# |prizes_category|prizes_overallMotivation|prizes_year|prizes_laureates_firstname|prizes_laureates_id|prizes_laureates_motivation                                    |prizes_laureates_share|prizes_laureates_surname|
# +---------------+------------------------+-----------+--------------------------+-------------------+---------------------------------------------------------------+----------------------+------------------------+
# |chemistry      |null                    |2019       |John                      |976                |"for the development of lithium-ion batteries"                 |3                     |Goodenough              |
# |chemistry      |null                    |2019       |M. Stanley                |977                |"for the development of lithium-ion batteries"                 |3                     |Whittingham             |
# |chemistry      |null                    |2019       |Akira                     |978                |"for the development of lithium-ion batteries"                 |3                     |Yoshino                 |
# |economics      |null                    |2019       |Abhijit                   |982                |"for their experimental approach to alleviating global poverty"|3                     |Banerjee                |
# |economics      |null                    |2019       |Esther                    |983                |"for their experimental approach to alleviating global poverty"|3                     |Duflo                   |
# +---------------+------------------------+-----------+--------------------------+-------------------+---------------------------------------------------------------+----------------------+------------------------+
# only showing top 5 rows

# %%
prizes_laureates_df.registerTempTable("nobel_prize")

# %% [markdown]
# # Nobel Prize winners more than once

# %%
spark.sql("""
select prizes_laureates_firstname,prizes_laureates_surname, count(*)  
from nobel_prize 
group by prizes_laureates_firstname, prizes_laureates_surname 
having count(*) > 1 
order by 3 desc 
""").show(20, False)
# Out:
# +-----------------------------------------------------------+------------------------+--------+
# |prizes_laureates_firstname                                 |prizes_laureates_surname|count(1)|
# +-----------------------------------------------------------+------------------------+--------+
# |International Committee of the Red Cross                   |null                    |3       |
# |Frederick                                                  |Sanger                  |2       |
# |Marie                                                      |Curie                   |2       |
# |Linus                                                      |Pauling                 |2       |
# |Office of the United Nations High Commissioner for Refugees|null                    |2       |
# |John                                                       |Bardeen                 |2       |
# +-----------------------------------------------------------+------------------------+--------+
